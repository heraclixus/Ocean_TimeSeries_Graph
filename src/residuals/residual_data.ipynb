# %%
import pandas as pd
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys
import time

# %%
data = scipy.io.loadmat('../../data/residual.mat')

# %%
data['residual'].shape
# Out:
# (887, 12, 20)

# %%
# plot for each of the 20 time series 
plt.figure(figsize=(15, 25))
plt.subplots(10,2)
for i in range(20):
    plt.subplot(10,2,i+1)
    plt.plot(np.abs(data['residual'][0,:,i]))
    plt.title(f'Time Series {i+1}')
plt.show()

# %%
pcs = np.load("../../data/sst_pcs.npy")

# %%
pcs.shape
# Out:
# (900, 20)
